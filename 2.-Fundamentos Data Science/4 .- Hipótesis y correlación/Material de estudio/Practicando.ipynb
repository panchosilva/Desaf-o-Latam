# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

sns.set_theme()

df = pd.read_csv("qog_std_cs_jan18.csv")
df.head()
# Out:
#    ccode        cname ccodealp  ccodecow  ccodewb        version  aid_cpnc  \
# 0      4  Afghanistan      AFG     700.0      4.0  QoGStdCSJan18       NaN
# 1      8      Albania      ALB     339.0      8.0  QoGStdCSJan18       NaN
# 2     12      Algeria      DZA     615.0     12.0  QoGStdCSJan18       NaN
# 3     20      Andorra      AND     232.0     20.0  QoGStdCSJan18       NaN
# 4     24       Angola      AGO     540.0     24.0  QoGStdCSJan18       NaN
#
#    aid_cpsc  aid_crnc  aid_crnio  ...  wvs_relacc  wvs_relsch  wvs_relsci  \
# 0       NaN      29.0       13.0  ...         NaN         NaN         NaN
# 1       NaN      26.0       13.0  ...         NaN         NaN         NaN
# 2       NaN      21.0        6.0  ...    3.710616    1.704692    3.681347
# 3       NaN       NaN        NaN  ...         NaN         NaN         NaN
# 4       NaN      22.0       13.0  ...         NaN         NaN         NaN
#
# ...

# %%
sns.displot(
    df['undp_hdi'],
    rug = True, #rallitas de abajo
    kde = True,#Asume una gaussiana
    fit = stats.norm,
    color = 'sienna',
)

plt.title("titulo")
plt.xlabel("EX's Label")
plt.ylabel("WHY LABELLLL")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-94d06e279a01> in <module>
#       3     rug = True, #rallitas de abajo
#       4     kde = True,#Asume una gaussiana
# ----> 5     fit = stats.norm,
#       6     color = 'sienna',
#       7 )
#
# NameError: name 'stats' is not defined

# %%
sns.countplot(y= df['ht_region'],
              order=df['ht_region'].value_counts().index #Ordena las regiones segun su cantidad de mayor a menor
             )
# Out:
# <AxesSubplot:xlabel='count', ylabel='ht_region'>

# %%
sns.countplot(y= df['ht_region'],
              order=df['ht_region'].value_counts().index, #Ordena las regiones segun su cantidad de mayor a menor
              hue = df['ccp_democ']
             )
# Out:
# <AxesSubplot:xlabel='count', ylabel='ht_region'>

# %%
sns.swarmplot(
    y=df['ht_region'],
    x=df['undp_hdi']
)
# Out:
# C:\Users\silva\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='undp_hdi', ylabel='ht_region'>

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(tips, col="time", row="sex") # De aquí también saldrán los títulos
g.set_axis_labels("label-x", "labe-y")

# %%
g = sns.FacetGrid(tips, col="time", row="sex") # 4 gráficos
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip") #Valores de X y valores de Y
g.set_axis_labels("Total bill", "Tip") # labels x e y

# %%
g = sns.FacetGrid(tips, col="time", hue="sex")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.set_axis_labels("Total bill", "Tip")
g.add_legend() #Sólo se agrega porque hay "hue" en la linea 1

# %%
g = sns.FacetGrid(tips, col="time", row="sex")
#g.map_dataframe(sns.boxplot) # sino se definene, el boxplot tomará todas las varaiables numéricas que pueda
g.map_dataframe(sns.boxplot, x = 'size', y="total_bill")

# %%
g = sns.FacetGrid(tips, col="sex", )
g.map_dataframe(sns.boxplot,y = 'tip')
